# %%
pip install google-genai
# Out:
# Requirement already satisfied: google-genai in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.8.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (4.14.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.55.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (49.0.0)
# Requirement already satisfied: certifi in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.7.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading speechrecognition-3.16.1-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: typing-extensions in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from SpeechRecognition) (4.15.0)
# Collecting standard-aifc (from SpeechRecognition)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting audioop-lts (from SpeechRecognition)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting standard-chunk (from standard-aifc->SpeechRecognition)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Downloading speechrecognition-3.16.1-py3-none-any.whl (32.9 MB)
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/32.9 MB 541.7 kB/s eta 0:01:00
#     --------------------------------------- 0.8/32.9 MB 640.8 kB/s eta 0:00:51
#     --------------------------------------- 0.8/32.9 MB 640.8 kB/s eta 0:00:51
#    - -------------------------------------- 1.0/32.9 MB 695.2 kB/s eta 0:00:46
#    - -------------------------------------- 1.0/32.9 MB 695.2 kB/s eta 0:00:46
#    - -------------------------------------- 1.3/32.9 MB 691.5 kB/s eta 0:00:46
#    - -------------------------------------- 1.6/32.9 MB 733.3 kB/s eta 0:00:43
#    -- ------------------------------------- 1.8/32.9 MB 764.6 kB/s eta 0:00:41
#    -- ------------------------------------- 1.8/32.9 MB 764.6 kB/s eta 0:00:41
#    -- ------------------------------------- 2.1/32.9 MB 783.6 kB/s eta 0:00:40
#    -- ------------------------------------- 2.4/32.9 MB 803.9 kB/s eta 0:00:38
#    --- ------------------------------------ 2.6/32.9 MB 825.9 kB/s eta 0:00:37
#    --- ------------------------------------ 2.6/32.9 MB 825.9 kB/s eta 0:00:37
#    --- ------------------------------------ 2.9/32.9 MB 853.1 kB/s eta 0:00:36
#    --- ------------------------------------ 3.1/32.9 MB 873.3 kB/s eta 0:00:35
#    ---- ----------------------------------- 3.4/32.9 MB 887.6 kB/s eta 0:00:34
#    ---- ----------------------------------- 3.7/32.9 MB 899.8 kB/s eta 0:00:33
#    ---- ----------------------------------- 3.9/32.9 MB 912.2 kB/s eta 0:00:32
#    ----- ---------------------------------- 4.2/32.9 MB 933.5 kB/s eta 0:00:31
#    ----- ---------------------------------- 4.5/32.9 MB 949.1 kB/s eta 0:00:30
#    ----- ---------------------------------- 4.7/32.9 MB 955.3 kB/s eta 0:00:30
#    ----- ---------------------------------- 4.7/32.9 MB 955.3 kB/s eta 0:00:30
#    ------ --------------------------------- 5.0/32.9 MB 951.8 kB/s eta 0:00:30
#    ------ --------------------------------- 5.2/32.9 MB 959.6 kB/s eta 0:00:29
#    ------ --------------------------------- 5.5/32.9 MB 960.7 kB/s eta 0:00:29
#    ------- -------------------------------- 5.8/32.9 MB 969.3 kB/s eta 0:00:28
#    ------- -------------------------------- 5.8/32.9 MB 969.3 kB/s eta 0:00:28
#    ------- -------------------------------- 6.3/32.9 MB 995.1 kB/s eta 0:00:27
#    ------- -------------------------------- 6.6/32.9 MB 999.9 kB/s eta 0:00:27
#    -------- ------------------------------- 6.8/32.9 MB 1.0 MB/s eta 0:00:26
#    -------- ------------------------------- 7.1/32.9 MB 1.0 MB/s eta 0:00:25
#    -------- ------------------------------- 7.3/32.9 MB 1.0 MB/s eta 0:00:25
#    --------- ------------------------------ 7.9/32.9 MB 1.1 MB/s eta 0:00:24
#    --------- ------------------------------ 7.9/32.9 MB 1.1 MB/s eta 0:00:24
#    ---------- ----------------------------- 8.4/32.9 MB 1.1 MB/s eta 0:00:23
#    ---------- ----------------------------- 8.7/32.9 MB 1.1 MB/s eta 0:00:23
#    ---------- ----------------------------- 8.9/32.9 MB 1.1 MB/s eta 0:00:22
#    ----------- ---------------------------- 9.2/32.9 MB 1.1 MB/s eta 0:00:22
#    ----------- ---------------------------- 9.4/32.9 MB 1.1 MB/s eta 0:00:22
#    ----------- ---------------------------- 9.7/32.9 MB 1.1 MB/s eta 0:00:21
#    ------------ --------------------------- 10.0/32.9 MB 1.1 MB/s eta 0:00:21
#    ------------ --------------------------- 10.5/32.9 MB 1.1 MB/s eta 0:00:20
#    ------------ --------------------------- 10.5/32.9 MB 1.1 MB/s eta 0:00:20
#    ------------- -------------------------- 10.7/32.9 MB 1.1 MB/s eta 0:00:20
#    ------------- -------------------------- 11.0/32.9 MB 1.1 MB/s eta 0:00:20
#    ------------- -------------------------- 11.3/32.9 MB 1.1 MB/s eta 0:00:19
#    -------------- ------------------------- 11.8/32.9 MB 1.2 MB/s eta 0:00:19
#    -------------- ------------------------- 12.1/32.9 MB 1.2 MB/s eta 0:00:18
#    --------------- ------------------------ 12.3/32.9 MB 1.2 MB/s eta 0:00:18
#    --------------- ------------------------ 12.3/32.9 MB 1.2 MB/s eta 0:00:18
#    --------------- ------------------------ 12.8/32.9 MB 1.2 MB/s eta 0:00:18
#    --------------- ------------------------ 12.8/32.9 MB 1.2 MB/s eta 0:00:18
#    --------------- ------------------------ 13.1/32.9 MB 1.2 MB/s eta 0:00:17
#    ---------------- ----------------------- 13.4/32.9 MB 1.2 MB/s eta 0:00:17
#    ---------------- ----------------------- 13.6/32.9 MB 1.2 MB/s eta 0:00:17
#    ---------------- ----------------------- 13.9/32.9 MB 1.2 MB/s eta 0:00:17
#    ----------------- ---------------------- 14.2/32.9 MB 1.2 MB/s eta 0:00:16
#    ----------------- ---------------------- 14.4/32.9 MB 1.2 MB/s eta 0:00:16
#    ----------------- ---------------------- 14.7/32.9 MB 1.2 MB/s eta 0:00:16
#    ------------------ --------------------- 14.9/32.9 MB 1.2 MB/s eta 0:00:16
#    ------------------ --------------------- 15.5/32.9 MB 1.2 MB/s eta 0:00:15
#    ------------------- -------------------- 15.7/32.9 MB 1.2 MB/s eta 0:00:15
#    ------------------- -------------------- 16.0/32.9 MB 1.2 MB/s eta 0:00:14
#    ------------------- -------------------- 16.3/32.9 MB 1.2 MB/s eta 0:00:14
#    -------------------- ------------------- 16.5/32.9 MB 1.2 MB/s eta 0:00:14
#    -------------------- ------------------- 17.0/32.9 MB 1.2 MB/s eta 0:00:13
#    --------------------- ------------------ 17.6/32.9 MB 1.2 MB/s eta 0:00:13
#    --------------------- ------------------ 17.8/32.9 MB 1.2 MB/s eta 0:00:13
#    ---------------------- ----------------- 18.1/32.9 MB 1.2 MB/s eta 0:00:12
#    ---------------------- ----------------- 18.4/32.9 MB 1.3 MB/s eta 0:00:12
#    ---------------------- ----------------- 18.9/32.9 MB 1.3 MB/s eta 0:00:12
#    ---------------------- ----------------- 18.9/32.9 MB 1.3 MB/s eta 0:00:12
#    ----------------------- ---------------- 19.1/32.9 MB 1.3 MB/s eta 0:00:11
#    ----------------------- ---------------- 19.4/32.9 MB 1.2 MB/s eta 0:00:11
#    ------------------------ --------------- 19.9/32.9 MB 1.3 MB/s eta 0:00:11
#    ------------------------ --------------- 20.2/32.9 MB 1.3 MB/s eta 0:00:11
#    ------------------------ --------------- 20.4/32.9 MB 1.3 MB/s eta 0:00:10
#    ------------------------- -------------- 20.7/32.9 MB 1.3 MB/s eta 0:00:10
#    ------------------------- -------------- 21.2/32.9 MB 1.3 MB/s eta 0:00:10
#    -------------------------- ------------- 21.5/32.9 MB 1.3 MB/s eta 0:00:09
#    -------------------------- ------------- 21.8/32.9 MB 1.3 MB/s eta 0:00:09
#    -------------------------- ------------- 22.0/32.9 MB 1.3 MB/s eta 0:00:09
#    --------------------------- ------------ 22.3/32.9 MB 1.3 MB/s eta 0:00:09
#    --------------------------- ------------ 22.5/32.9 MB 1.3 MB/s eta 0:00:09
#    --------------------------- ------------ 22.8/32.9 MB 1.3 MB/s eta 0:00:08
#    ---------------------------- ----------- 23.1/32.9 MB 1.3 MB/s eta 0:00:08
#    ---------------------------- ----------- 23.3/32.9 MB 1.3 MB/s eta 0:00:08
#    ---------------------------- ----------- 23.6/32.9 MB 1.3 MB/s eta 0:00:08
#    ----------------------------- ---------- 23.9/32.9 MB 1.3 MB/s eta 0:00:07
#    ----------------------------- ---------- 24.1/32.9 MB 1.3 MB/s eta 0:00:07
#    ----------------------------- ---------- 24.1/32.9 MB 1.3 MB/s eta 0:00:07
#    ----------------------------- ---------- 24.1/32.9 MB 1.3 MB/s eta 0:00:07
#    ----------------------------- ---------- 24.4/32.9 MB 1.3 MB/s eta 0:00:07
#    ------------------------------ --------- 25.2/32.9 MB 1.3 MB/s eta 0:00:07
#    ------------------------------ --------- 25.4/32.9 MB 1.3 MB/s eta 0:00:06
#    ------------------------------ --------- 25.4/32.9 MB 1.3 MB/s eta 0:00:06
#    ------------------------------- -------- 25.7/32.9 MB 1.3 MB/s eta 0:00:06
#    ------------------------------- -------- 26.2/32.9 MB 1.3 MB/s eta 0:00:06
#    -------------------------------- ------- 26.5/32.9 MB 1.3 MB/s eta 0:00:05
#    -------------------------------- ------- 26.7/32.9 MB 1.3 MB/s eta 0:00:05
#    -------------------------------- ------- 27.0/32.9 MB 1.3 MB/s eta 0:00:05
#    --------------------------------- ------ 27.3/32.9 MB 1.3 MB/s eta 0:00:05
#    --------------------------------- ------ 27.5/32.9 MB 1.3 MB/s eta 0:00:05
#    ---------------------------------- ----- 28.0/32.9 MB 1.3 MB/s eta 0:00:04
#    ---------------------------------- ----- 28.3/32.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 28.8/32.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------------------- ---- 29.1/32.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------ --- 29.6/32.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------ --- 30.1/32.9 MB 1.3 MB/s eta 0:00:03
#    ------------------------------------- -- 30.7/32.9 MB 1.3 MB/s eta 0:00:02
#    ------------------------------------- -- 30.9/32.9 MB 1.3 MB/s eta 0:00:02
#    -------------------------------------- - 31.5/32.9 MB 1.4 MB/s eta 0:00:02
#    -------------------------------------- - 32.0/32.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  32.5/32.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------  32.8/32.9 MB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 32.9/32.9 MB 1.4 MB/s  0:00:24
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Installing collected packages: standard-chunk, audioop-lts, standard-aifc, SpeechRecognition
#
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ------------------------------ --------- 3/4 [SpeechRecognition]
#    ---------------------------------------- 4/4 [SpeechRecognition]
#
# Successfully installed SpeechRecognition-3.16.1 audioop-lts-0.2.2 standard-aifc-3.13.0 standard-chunk-3.13.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script sprc.exe is installed in 'c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install pyttsx3 pyaudio
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Collecting pyaudio
#   Downloading PyAudio-0.2.14.tar.gz (47 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting comtypes (from pyttsx3)
#   Downloading comtypes-1.4.16-py3-none-any.whl.metadata (7.8 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Downloading pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Collecting pywin32 (from pyttsx3)
#   Downloading pywin32-312-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Downloading pyttsx3-2.99-py3-none-any.whl (32 kB)
# Downloading comtypes-1.4.16-py3-none-any.whl (296 kB)
# Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Downloading pywin32-312-cp314-cp314-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.0 MB 607.6 kB/s eta 0:00:11
#    -- ------------------------------------- 0.5/7.0 MB 607.6 kB/s eta 0:00:11
#    ---- ----------------------------------- 0.8/7.0 MB 620.0 kB/s eta 0:00:11
#    ----- ---------------------------------- 1.0/7.0 MB 710.6 kB/s eta 0:00:09
#    ----- ---------------------------------- 1.0/7.0 MB 710.6 kB/s eta 0:00:09
#    ------- -------------------------------- 1.3/7.0 MB 750.6 kB/s eta 0:00:08
#    -------- ------------------------------- 1.6/7.0 MB 804.9 kB/s eta 0:00:07
#    ---------- ----------------------------- 1.8/7.0 MB 857.1 kB/s eta 0:00:07
#    ----------- ---------------------------- 2.1/7.0 MB 889.6 kB/s eta 0:00:06
#    ----------- ---------------------------- 2.1/7.0 MB 889.6 kB/s eta 0:00:06
#    ------------- -------------------------- 2.4/7.0 MB 875.0 kB/s eta 0:00:06
#    -------------- ------------------------- 2.6/7.0 MB 909.7 kB/s eta 0:00:05
#    ----------------- ---------------------- 3.1/7.0 MB 990.3 kB/s eta 0:00:04
#    ----------------- ---------------------- 3.1/7.0 MB 990.3 kB/s eta 0:00:04
#    ------------------- -------------------- 3.4/7.0 MB 991.5 kB/s eta 0:00:04
#    ---------------------- ----------------- 3.9/7.0 MB 1.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.2/7.0 MB 1.1 MB/s eta 0:00:03
#    ------------------------- -------------- 4.5/7.0 MB 1.1 MB/s eta 0:00:03
#    -------------------------- ------------- 4.7/7.0 MB 1.1 MB/s eta 0:00:03
#    ---------------------------- ----------- 5.0/7.0 MB 1.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 5.0/7.0 MB 1.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 5.2/7.0 MB 1.1 MB/s eta 0:00:02
#    ------------------------------- -------- 5.5/7.0 MB 1.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 6.0/7.0 MB 1.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 6.3/7.0 MB 1.1 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.0 MB 1.2 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 1.2 MB/s  0:00:06
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (pyproject.toml): started
#   Building wheel for pyaudio (pyproject.toml): finished with status 'error'
# Failed to build pyaudio
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Building wheel for pyaudio (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [22 lines of output]
#       WARNING:root:Warning: VCPKG_PATH envrionment variable not set.
#       C:\Users\ekica\AppData\Local\Temp\pip-build-env-oyhx2kwm\overlay\Lib\site-packages\setuptools\dist.py:765: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: MIT License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       INFO:root:running bdist_wheel
#       INFO:root:running build
#       INFO:root:running build_py
#       INFO:root:creating build\lib.win-amd64-cpython-314\pyaudio
#       INFO:root:copying src\pyaudio\__init__.py -> build\lib.win-amd64-cpython-314\pyaudio
#       INFO:root:running build_ext
#       INFO:root:building 'pyaudio._portaudio' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pyaudio
# error: failed-wheel-build-for-install
#
# × Failed to build installable wheels for some pyproject.toml based projects
# ╰─> pyaudio

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Using cached pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Collecting comtypes (from pyttsx3)
#   Using cached comtypes-1.4.16-py3-none-any.whl.metadata (7.8 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Collecting pywin32 (from pyttsx3)
#   Using cached pywin32-312-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Using cached pyttsx3-2.99-py3-none-any.whl (32 kB)
# Using cached comtypes-1.4.16-py3-none-any.whl (296 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# Using cached pywin32-312-cp314-cp314-win_amd64.whl (7.0 MB)
# Installing collected packages: pywin32, comtypes, pypiwin32, pyttsx3
#
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------------------------------------- 0/4 [pywin32]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ---------- ----------------------------- 1/4 [comtypes]
#    ------------------------------ --------- 3/4 [pyttsx3]
#    ------------------------------ --------- 3/4 [pyttsx3]
#    ---------------------------------------- 4/4 [pyttsx3]
#
# Successfully installed comtypes-1.4.16 pypiwin32-223 pyttsx3-2.99 pywin32-312
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pywin32_postinstall.exe and pywin32_testall.exe are installed in 'c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script clear_comtypes_cache.exe is installed in 'c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pip install groq
# Out:
# Collecting groq
#   Downloading groq-1.4.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from groq) (4.14.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from groq) (2.13.4)
# Requirement already satisfied: sniffio in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from anyio<5,>=3.5.0->groq) (3.18)
# Requirement already satisfied: certifi in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->groq) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.4.0-py3-none-any.whl (143 kB)
# Installing collected packages: groq
# Successfully installed groq-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 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

# %%
pip uninstall pyaudio -y
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Skipping pyaudio as it is not installed.

# %%
pip install pipwin
# Out:
# Collecting pipwin
#   Downloading pipwin-0.5.2.tar.gz (7.9 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting docopt (from pipwin)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: requests in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pipwin) (2.34.2)
# Collecting pyprind (from pipwin)
#   Downloading PyPrind-2.11.3-py2.py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from pipwin) (1.17.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pipwin) (4.15.0)
# Collecting js2py (from pipwin)
#   Downloading Js2Py-0.74-py3-none-any.whl.metadata (868 bytes)
# Requirement already satisfied: packaging in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from pipwin) (26.2)
# Collecting pySmartDL>=1.3.1 (from pipwin)
#   Downloading pySmartDL-1.3.4-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4>=4.9.0->pipwin) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from beautifulsoup4>=4.9.0->pipwin) (4.15.0)
# Collecting tzlocal>=1.2 (from js2py->pipwin)
#   Downloading tzlocal-5.4.3-py3-none-any.whl.metadata (7.7 kB)
# Collecting pyjsparser>=2.5.1 (from js2py->pipwin)
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tzdata in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from tzlocal>=1.2->js2py->pipwin) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->pipwin) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->pipwin) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->pipwin) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->pipwin) (2026.5.20)
# Downloading pySmartDL-1.3.4-py3-none-any.whl (20 kB)
# Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ------------------------------ --------- 0.8/1.0 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 2.6 MB/s  0:00:00
# Downloading tzlocal-5.4.3-py3-none-any.whl (18 kB)
# Downloading PyPrind-2.11.3-py2.py3-none-any.whl (8.4 kB)
# Building wheels for collected packages: pipwin, docopt, pyjsparser
#   Building wheel for pipwin (pyproject.toml): started
#   Building wheel for pipwin (pyproject.toml): finished with status 'done'
#   Created wheel for pipwin: filename=pipwin-0.5.2-py2.py3-none-any.whl size=8863 sha256=70d7edce4f7fdc36b4af89dc2c353e8729078b09362498a8759416afa1bcbc55
#   Stored in directory: c:\users\ekica\appdata\local\pip\cache\wheels\73\03\c1\1ed9c5626efe8c0c06ec002247943624b4e057f7c93c124051
#   Building wheel for docopt (pyproject.toml): started
#   Building wheel for docopt (pyproject.toml): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13887 sha256=9c869587f62422953cae8aaf7965eb80e7e248618806bf4655ff3d48a8ddbaa2
#   Stored in directory: c:\users\ekica\appdata\local\pip\cache\wheels\79\6f\5f\26c3d1a144117ef52122d67c32b9f3c297c3dec4fea00a31ac
#   Building wheel for pyjsparser (pyproject.toml): started
#   Building wheel for pyjsparser (pyproject.toml): finished with status 'done'
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25762 sha256=d483677a15ea54b6b8c2f55856ccb6cf17055d08aff4e85ed7b38b69e9d49acc
#   Stored in directory: c:\users\ekica\appdata\local\pip\cache\wheels\c7\4a\4a\faea8faa646e9dee97574d1820a2eed10bc041aa3802e5db87
# Successfully built pipwin docopt pyjsparser
# Installing collected packages: pySmartDL, pyprind, pyjsparser, docopt, tzlocal, js2py, pipwin
#
#    ---------------------------------------- 0/7 [pySmartDL]
#    ----- ---------------------------------- 1/7 [pyprind]
#    ----------------- ---------------------- 3/7 [docopt]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------- ----------- 5/7 [js2py]
#    ---------------------------------- ----- 6/7 [pipwin]
#    ---------------------------------------- 7/7 [pipwin]
#
# Successfully installed docopt-0.6.2 js2py-0.74 pipwin-0.5.2 pySmartDL-1.3.4 pyjsparser-2.7.1 pyprind-2.11.3 tzlocal-5.4.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script pipwin.exe is installed in 'c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
pipwin install pyaudio
# Out:
#   Cell In[4], line 1
#     pipwin install pyaudio
#            ^
# SyntaxError: invalid syntax

# %%
pip install pipwin --upgrade
# Out:
# Requirement already satisfied: pipwin in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.5.2)
# Requirement already satisfied: docopt in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pipwin) (0.6.2)
# Requirement already satisfied: requests in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pipwin) (2.34.2)
# Requirement already satisfied: pyprind in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pipwin) (2.11.3)
# Requirement already satisfied: six in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from pipwin) (1.17.0)
# Requirement already satisfied: beautifulsoup4>=4.9.0 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pipwin) (4.15.0)
# Requirement already satisfied: js2py in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pipwin) (0.74)
# Requirement already satisfied: packaging in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from pipwin) (26.2)
# Requirement already satisfied: pySmartDL>=1.3.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pipwin) (1.3.4)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from beautifulsoup4>=4.9.0->pipwin) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\ekica\AppData\Roaming\Python\Python314\site-packages (from beautifulsoup4>=4.9.0->pipwin) (4.15.0)
# Requirement already satisfied: tzlocal>=1.2 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from js2py->pipwin) (5.4.3)
# Requirement already satisfied: pyjsparser>=2.5.1 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from js2py->pipwin) (2.7.1)
# Requirement already satisfied: tzdata in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from tzlocal>=1.2->js2py->pipwin) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->pipwin) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->pipwin) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->pipwin) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from requests->pipwin) (2026.5.20)
# Note: you may need to restart the kernel to use updated packages.

# %%
pipwin refresh
pipwin install pyaudio
# Out:
#   Cell In[1], line 1
#     pipwin refresh
#            ^
# SyntaxError: invalid syntax

# %%
pip install C:\Users\ekica\Downloads\PyAudio-0.2.14-cp314-cp314-win_amd64.whl
# Out:
# Processing C:\Users\ekica\Downloads\PyAudio-0.2.14-cp314-cp314-win_amd64.whl
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Requirement 'C:\\Users\\ekica\\Downloads\\PyAudio-0.2.14-cp314-cp314-win_amd64.whl' looks like a filename, but the file does not exist
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\Users\\ekica\\Downloads\\PyAudio-0.2.14-cp314-cp314-win_amd64.whl'

# %%
pip install sounddevice
# Out:
# Collecting sounddevice
#   Downloading sounddevice-0.5.5-py3-none-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: cffi in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from sounddevice) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\ekica\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from cffi->sounddevice) (3.0)
# Downloading sounddevice-0.5.5-py3-none-win_amd64.whl (365 kB)
# Installing collected packages: sounddevice
# Successfully installed sounddevice-0.5.5
# Note: you may need to restart the kernel to use updated packages.
